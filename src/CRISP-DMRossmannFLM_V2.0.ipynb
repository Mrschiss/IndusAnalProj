# %% [markdown]
# # AIM - Data Science & AI Business Project

# %% [raw]
# # Applying the CRISP-DM Method to a Business Problem - ROSSMANN Drogeriemarkt sales prediction
# # Taken and adopted to own needs from https://github.com/mbenetti/CRISP-DM-Rossmann

# %% [markdown]
# ## Getting Started

# %% [markdown]
# #### Importing libraries

# %%
# Pandas is a Python library used for working with data sets.
# It has functions for analyzing, cleaning, exploring, and manipulating data.
# https://www.w3schools.com/python/pandas/default.asp
# https://pypi.org/project/pandas/
import pandas as pd

# Never print warning messages
import warnings
warnings.filterwarnings("ignore")

# -------------------------------------------------------------------------
# Import Matplotlib library and assigns shorthand 'plt'
import matplotlib
import matplotlib.pyplot as plt
# Imports Seaborn library and assigns shorthand 'sns'
import seaborn as sns
# Imports Plotly library and assigns shorthand 'px'
import plotly.express as px
# Imports Numpy library and assigns shorthand 'np'
import numpy as np

# %%
# Checking Pandas Version before using it
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# ## 1. Business Understanding

# %% [raw]
# This Project describes how to apply CRISP-DM to a specific business case about sales data analysis.

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# ### 2.1 Initial data report

# %% [markdown]
# #### Reading data (train, test, store)

# %%
# Importing train, test and store data to the notebook
# Dealing with Time Series Data by using Pandas’ parse_dates

train = pd.read_csv("C:\Data\RossmanSalesData/train.csv", 
                    parse_dates = True, low_memory = False, index_col = 'Date')
test = pd.read_csv("C:\Data\RossmanSalesData/test.csv", 
                    parse_dates = True, low_memory = False, index_col = 'Date')

# the additional store data

store = pd.read_csv("C:\Data\RossmanSalesData/store.csv", 
                    low_memory = False)

# time series as indexes, verification step for indexes, uncomment in case is need it
#train.index
#test.index

# %% [markdown]
# ### 2.2 Describing data (train, test, store)

# %% [raw]
# Describe dataframe: shape, column names, datatypes, value ranges
# df.shape
# df.head()
# df.tail()
# df.info()
# df.describe()
# df.describe(include=object)
# df.dtypes

# %% [markdown]
# #### Train data

# %% [raw]
# Describe data train
# train.shape, train.head(), train.tail(), train.info(), train.describe(), train.describe(include=object)
# train.nlargest(5,'Sales')
# train.nlargest(3,'Customers')
# train.nsmallest(3,'Sales')
# train.nsmallest(3,'Customers')

# %%
# Describing data train
print("In total: ", train.shape)
# Out:
# In total:  (1017209, 8)

# %%
# Describing data train
print(train.head())
# print(train.tail())
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-31      2          5   6064        625     1      1            0
# 2015-07-31      3          5   8314        821     1      1            0
# 2015-07-31      4          5  13995       1498     1      1            0
# 2015-07-31      5          5   4822        559     1      1            0
#
#             SchoolHoliday
# Date
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1

# %%
# Describing data train
print(train.info())
# The info() method also tells us how many Non-Null values there are present in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1017209 entries, 2015-07-31 to 2013-01-01
# Data columns (total 8 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Sales          1017209 non-null  int64
#  3   Customers      1017209 non-null  int64
#  4   Open           1017209 non-null  int64
#  5   Promo          1017209 non-null  int64
#  6   StateHoliday   1017209 non-null  object
#  7   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 69.8+ MB
# None

# %%
# Describing data train
# Describing numerical columns
train.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# ...

# %%
# Describing data train
# Describing non-numerical columns
train.describe(include=object)
# Out:
#        StateHoliday
# count       1017209
# unique            4
# top               0
# freq         986159

# %%
# Describing data train
# Select and order top n entries (largest and smallest)
train.nlargest(5,'Sales')
# train.nlargest(3,'Customers')
# train.nsmallest(3,'Sales')
# train.nsmallest(3,'Customers')
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-06-22    909          1  41551       1721     1      0            0
# 2015-04-03    262          5  38722       5132     1      1            b
# 2015-05-01    262          5  38484       5458     1      1            a
# 2015-05-14    262          4  38367       5192     1      0            a
# 2014-06-16     57          1  38037       1970     1      1            0
#
#             SchoolHoliday
# Date
# 2015-06-22              0
# 2015-04-03              0
# 2015-05-01              0
# 2015-05-14              1
# 2014-06-16              0

# %%
#overview of values and their counts
train[("DayOfWeek")].value_counts(dropna=False)
# Out:
# DayOfWeek
# 5    145845
# 4    145845
# 3    145665
# 2    145664
# 1    144730
# 7    144730
# 6    144730
# Name: count, dtype: int64

# %% [markdown]
# #### Test data

# %% [raw]
# Describe data: shape, column names, datatypes, value ranges
# test.shape
# test.head()
# test.tail()
# test.info()
# test.describe()
# test.describe(include=object)

# %%
# Describing data test
print("In total: ", test.shape)
# Out:
# In total:  (41088, 7)

# %%
# Describing data test
print(test.head())
# print(test.tail())
# Out:
#             Id  Store  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday
# Date
# 2015-09-17   1      1          4   1.0      1            0              0
# 2015-09-17   2      3          4   1.0      1            0              0
# 2015-09-17   3      7          4   1.0      1            0              0
# 2015-09-17   4      8          4   1.0      1            0              0
# 2015-09-17   5      9          4   1.0      1            0              0

# %%
# Describing data test
print(test.info())
# The info() method also tells us how many Non-Null values there are present in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 41088 entries, 2015-09-17 to 2015-08-01
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Open           41077 non-null  float64
#  4   Promo          41088 non-null  int64
#  5   StateHoliday   41088 non-null  object
#  6   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 2.5+ MB
# None

# %%
# Describing data test
# Exploring numerical columns
test.describe()
# Out:
#                  Id         Store     DayOfWeek          Open         Promo  \
# count  41088.000000  41088.000000  41088.000000  41077.000000  41088.000000
# mean   20544.500000    555.899533      3.979167      0.854322      0.395833
# std    11861.228267    320.274496      2.015481      0.352787      0.489035
# min        1.000000      1.000000      1.000000      0.000000      0.000000
# 25%    10272.750000    279.750000      2.000000      1.000000      0.000000
# 50%    20544.500000    553.500000      4.000000      1.000000      0.000000
# 75%    30816.250000    832.250000      6.000000      1.000000      1.000000
# max    41088.000000   1115.000000      7.000000      1.000000      1.000000
#
#        SchoolHoliday
# count   41088.000000
# mean        0.443487
# std         0.496802
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %%
# Describing data test
# Describing non-numerical columns
test.describe(include=object)
# Out:
#        StateHoliday
# count         41088
# unique            2
# top               0
# freq          40908

# %% [markdown]
# #### Store data

# %% [raw]
# Describe data: shape, column names, datatypes, value ranges
# store.shape
# store.head()
# store.tail()
# store.info()
# store.describe()
# store.describe(include=object)
# store.nlargest(3,'CompetitionDistance')
# store.nsmallest(3,'CompetitionDistance')

# %%
# Describing data store
print("In total: ", store.shape)
# Out:
# In total:  (1115, 10)

# %%
# Describing data store
print(store.head())
# print(store.tail())
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
# Describing data store
print(store.info())
# The info() method also tells us how many Non-Null values there are present in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB
# None

# %%
# Describing data store
# Describing numerical columns
store.describe()
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1112.000000                 761.000000
# mean    558.00000          5404.901079                   7.224704
# std     322.01708          7663.174720                   3.212348
# min       1.00000            20.000000                   1.000000
# 25%     279.50000           717.500000                   4.000000
# 50%     558.00000          2325.000000                   8.000000
# 75%     836.50000          6882.500000                  10.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count                761.000000  1115.000000       571.000000       571.000000
# mean                2008.668857     0.512108        23.595447      2011.763573
# std                    6.195983     0.500078        14.141984         1.674935
# ...

# %%
# Describing data store
# Describing non-numerical columns
store.describe(include=object)
# Out:
#        StoreType Assortment    PromoInterval
# count       1115       1115              571
# unique         4          3                3
# top            a          a  Jan,Apr,Jul,Oct
# freq         602        593              335

# %%
# Describing data store
# Select and order top n entries (largest and smallest)
store.nlargest(3,'CompetitionDistance')
# store.nsmallest(3,'CompetitionDistance')
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 452    453         a          c              75860.0
# 121    122         a          c              58260.0
# 800    801         d          a              48330.0
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 452                        NaN                       NaN       0
# 121                        4.0                    2013.0       0
# 800                        4.0                    2013.0       0
#
#      Promo2SinceWeek  Promo2SinceYear PromoInterval
# 452              NaN              NaN           NaN
# 121              NaN              NaN           NaN
# 800              NaN              NaN           NaN

# %% [markdown]
# ### 2.3 Verify data quality

# %% [markdown]
# #### 2.3.1 Missing values / Completeness

# %% [markdown]
# ##### Null values / Missing values

# %%
# check null values
# train.isnull().sum()
# test.isnull().sum()
store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
missing_values_table(train)
# Out:
# Your selected dataframe has 8 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
missing_values_table(test)
# Out:
# Your selected dataframe has 7 columns.
# There are 1 columns that have missing values.
#       Missing Values  % of Total Values
# Open              11                0.0

# %%
missing_values_table(store)
# Out:
# Your selected dataframe has 10 columns.
# There are 6 columns that have missing values.
#                            Missing Values  % of Total Values
# Promo2SinceYear                       544               48.8
# Promo2SinceWeek                       544               48.8
# PromoInterval                         544               48.8
# CompetitionOpenSinceMonth             354               31.7
# CompetitionOpenSinceYear              354               31.7
# CompetitionDistance                     3                0.3

# %% [markdown]
# ##### Closed stores and zero sales

# %%
# closed stores and zero sales
train[(train.Open == 0) & (train.Sales == 0)].shape
# Out:
# (172817, 8)

# %% [markdown]
# ##### Opened stores with zero sales

# %%
# opened stores with zero sales
zero_sales = train[(train.Open != 0) & (train.Sales == 0)]
print("In total: ", zero_sales.shape)
zero_sales.head(5)
# Out:
# In total:  (54, 8)
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-05-15    971          5      0          0     1      0            0
# 2015-03-26    674          4      0          0     1      0            0
# 2015-02-05    699          4      0          0     1      1            0
# 2014-10-01    708          3      0          0     1      1            0
# 2014-09-22    357          1      0          0     1      0            0
#
#             SchoolHoliday
# Date
# 2015-05-15              1
# 2015-03-26              0
# 2015-02-05              0
# 2014-10-01              0
# 2014-09-22              0

# %% [markdown]
# #### 2.3.2 Outliers detection / Accuracy

# %% [markdown]
# ##### Plot all sales per day

# %%
x=train['Sales']
print("In total: ", x.shape)
plt.plot(x)
# Out:
# In total:  (1017209,)

# %% [markdown]
# ##### Plot sales distribution histogram

# %%
# stores with zero sales
train[(train.Sales == 0)].shape
# Out:
# (172871, 8)

# %%
# Plot sales distributionn including 172871 rows with zero sales 
sns.histplot(train['Sales'], bins=100)
plt.title('Sales Distribution Histogram')
plt.show()

# %% [markdown]
# ##### Boxplot for sales by day of the week

# %%
# Boxplot for sales by day of the week
# import seaborn as sns
# import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='DayOfWeek', y='Sales', data=train)
plt.title('Sales Distribution by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# #### Data Prep! Delete rows from train data for closed stores and days which didn't have any sales

# %%
print("Closed stores and days which didn't have any sales won't be counted into the forecasts. The remaining stores are: ")
train_n = train[(train["Open"] != 0) & (train['Sales'] != 0)]
# Out:
# Closed stores and days which didn't have any sales won't be counted into the forecasts. The remaining stores are:

# %%
print("In total: ", train_n.shape)
# Out:
# In total:  (844338, 8)

# %%
x=train_n['Sales']
print("In total: ", x.shape)
plt.plot(x)
# Out:
# In total:  (844338,)

# %%
# Plot sales distribution
sns.histplot(train_n['Sales'], bins=100)
plt.title('Sales Distribution Histogram')
plt.show()

# %% [markdown]
# ##### Boxplot for sales by day of the week without stores closed

# %%
# Boxplot for sales by day of the week (train data without stores closed!)
# import seaborn as sns
# import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='DayOfWeek', y='Sales', data=train_n)
plt.title('Sales Distribution by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Sales')
plt.show()

# %%
# Reducing train_n (without stores closed) to sales <= 12500
train_n_red = train_n[train_n.Sales <= 12500]
print("Reduced dataset train: ", train_n_red.shape)
# Out:
# Reduced dataset train:  (799603, 8)

# %% [markdown]
# ##### Boxplot for sales by day of the week with reduced train data

# %%
# Boxplot for Sales by Day of the Week for opened stores with reduced train data

plt.figure(figsize=(10, 6))
sns.boxplot(x='DayOfWeek', y='Sales', data=train_n_red)
plt.title('Sales Distribution by Day of the Week - reduced dataset train (Sales <= 12500)')
plt.xlabel('Day of the Week')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ##### Boxplot for sales by day of the week for whole dataset (without closed stores)

# %%
# Boxplot for Sales by Day of the Week for opened stores
# renaming day numbers into day names and append column DayName

day_map = {
    1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday',
    5: 'Friday', 6: 'Saturday', 7: 'Sunday'
}
train_n['DayName'] = train_n['DayOfWeek'].map(day_map)

plt.figure(figsize=(10, 6))
sns.boxplot(x='DayName', y='Sales', data=train_n, order=[
            'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Sales Distribution by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ##### Boxplot for log-transformed sales distribution

# %%
# Log-transformed sales distribution (without stores closed)
# Making the distribution more symmetric, reducing the influence of extreme outliers and 
# Achiving better results with regression models, since many models learn linear relationships more effectively

plt.figure(figsize=(10, 6))

train_n['LogSales'] = np.log1p(train_n['Sales'])  # log1p für log(1 + x)

sns.boxplot(x='DayName', y='LogSales', data=train_n[train_n['Open'] == 1], order=[
            'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Log-Transformed Sales Distribution')
plt.xlabel('Day of the Week')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(train_n['Sales'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of the original sales figures')
plt.xlabel('Sales')
plt.ylabel('Amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(train_n['LogSales'], bins=50, color='lightgreen', edgecolor='black')
plt.title('Distribution of log-transormed sales figures')
plt.xlabel('Log(1 + Sales)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# ##### Boxplot for sales distribution

# %%
# Boxplot for sales distribution (reduced dataset train without stores closed)
# import seaborn as sns
# import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='Sales', data=train_n_red)
plt.title('Sales Distribution - - reduced dataset train (Sales <= 12500)')
plt.xlabel('Sales')
plt.show()

# %%
# Boxplot for sales distribution without stores closed
# import seaborn as sns
# import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='Sales', data=train_n)
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.show()

# %% [markdown]
# ##### Boxplot for sales on holidays vs. non-holidays

# %%
# Boxplot for sales on holidays vs. non-holidays - without stores closed
plt.figure(figsize=(8, 6))
sns.boxplot(x='StateHoliday', y='Sales', data=train_n)
plt.title('Sales by State Holiday Type')
plt.xlabel('State Holiday')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ##### Boxblot for sales by store (for a subset)

# %%
# Boxblot for sales by store (for a subset)
subset_stores = train_n['Store'].unique()[:10]  # first 10 stores
subset_df = train_n[train_n['Store'].isin(subset_stores)]

plt.figure(figsize=(12, 6))
sns.boxplot(x='Store', y='Sales', data=subset_df)
plt.title('Sales Distribution by Store (First 10 Stores)')
plt.xlabel('Store')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# #### 2.3.3 Data Quality Report

# %% [raw]
# Missing values:
# Train data: no missing values
# Test data:
#   Open             11
# Store data:
#   CompetitionDistance            3
#   CompetitionOpenSinceMonth    354
#   CompetitionOpenSinceYear     354
#   Promo2SinceWeek              544
#   Promo2SinceYear              544
#   PromoInterval                544
#
# Outliers:
# No outliers detected
#
# Note:
# 1. Deleted rows from train data for closed stores and days which didn't have any sales; new dataframe is called train_n
# 2. Sales figures are right-skewed (many small values, few large ones). A log transformation helps to make the distribution more symmetric
# 3. Table Store, Column CompetitionDistance (3 values NaN): NaN to be filled with a median value (skewed distribuion) ->Data Preparation
# 4. Table Store, Column Promo2SinceWeek: Filling NaN with a median value (skewed distribuion) -> Data Preparation

# %% [markdown]
# ### 2.4 First Data Exploration

# %% [raw]
# Additional information about data stores

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
missing_values_table(store)
# Out:
# Your selected dataframe has 10 columns.
# There are 6 columns that have missing values.
#                            Missing Values  % of Total Values
# Promo2SinceYear                       544               48.8
# Promo2SinceWeek                       544               48.8
# PromoInterval                         544               48.8
# CompetitionOpenSinceMonth             354               31.7
# CompetitionOpenSinceYear              354               31.7
# CompetitionDistance                     3                0.3

# %%
# Aditional feature creation for time analysis before the join
# Ensure the index is a datetime object
# print(train.index)
train_n.index = pd.to_datetime(train_n.index)
print(train_n.index)

train_n['Year'] = train_n.index.year
train_n['Month'] = train_n.index.month
train_n['Day'] = train_n.index.day

# adding new variable
train_n['SalePerCustomer'] = train_n['Sales']/train_n['Customers']
#train_n['SalePerCustomer'].describe()
# Out:
# DatetimeIndex(['2015-07-31', '2015-07-31', '2015-07-31', '2015-07-31',
#                '2015-07-31', '2015-07-31', '2015-07-31', '2015-07-31',
#                '2015-07-31', '2015-07-31',
#                ...
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01'],
#               dtype='datetime64[ns]', name='Date', length=844338, freq=None)

# %%
train_n['Year'].value_counts()
# train['Month'].value_counts()
# Out:
# Year
# 2013    337924
# 2014    310385
# 2015    196029
# Name: count, dtype: int64

# %%
# ----------------------------------------------------------------------------------------------------------------------------
# Exploring Data train after several columns have been added
print("In total: ", train_n.shape)
# Out:
# In total:  (844338, 14)

# %%
# Analyzing Data train
print(train_n.head())
# print(train_n.tail())
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-31      2          5   6064        625     1      1            0
# 2015-07-31      3          5   8314        821     1      1            0
# 2015-07-31      4          5  13995       1498     1      1            0
# 2015-07-31      5          5   4822        559     1      1            0
#
#             SchoolHoliday DayName  LogSales  Year  Month  Day  SalePerCustomer
# Date
# 2015-07-31              1  Friday  8.568646  2015      7   31         9.482883
# 2015-07-31              1  Friday  8.710290  2015      7   31         9.702400
# 2015-07-31              1  Friday  9.025816  2015      7   31        10.126675
# 2015-07-31              1  Friday  9.546527  2015      7   31         9.342457
# 2015-07-31              1  Friday  8.481151  2015      7   31         8.626118

# %%
# Exploring Data train
print(train_n.info())
# The info() method also tells us how many Non-Null values there are present in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 844338 entries, 2015-07-31 to 2013-01-01
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Store            844338 non-null  int64
#  1   DayOfWeek        844338 non-null  int64
#  2   Sales            844338 non-null  int64
#  3   Customers        844338 non-null  int64
#  4   Open             844338 non-null  int64
#  5   Promo            844338 non-null  int64
#  6   StateHoliday     844338 non-null  object
#  7   SchoolHoliday    844338 non-null  int64
#  8   DayName          844338 non-null  object
#  9   LogSales         844338 non-null  float64
#  10  Year             844338 non-null  int32
#  11  Month            844338 non-null  int32
#  12  Day              844338 non-null  int32
#  13  SalePerCustomer  844338 non-null  float64
# dtypes: float64(2), int32(3), int64(7), object(2)
# memory usage: 87.0+ MB
# None

# %%
# Useful scatterplots for data exploration
# Set Seaborn style
sns.set(style="whitegrid", context="notebook")

# 1. Sales vs Customers
plt.figure(figsize=(8, 6))
sns.scatterplot(data=train_n, x='Customers', y='Sales', alpha=0.3)
plt.title("Sales vs Customers")
plt.xlabel("Customers")
plt.ylabel("Sales")
plt.show()

# %%
# 2. Sales per Customer vs Promo
plt.figure(figsize=(8, 6))
sns.scatterplot(data=train_n, x='Promo', y='SalePerCustomer', alpha=0.3)
plt.title("SalePerCustomer vs Promo")
plt.xlabel("Promo")
plt.ylabel("Sales per Customer")
plt.show()

# %%
# 3. Sales vs DayOfWeek (color by Promo)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=train_n, x='DayOfWeek', y='Sales', hue='Promo', alpha=0.3)
plt.title("Sales vs DayOfWeek (Promo Highlighted)")
plt.xlabel("Day of Week")
plt.ylabel("Log of Sales")
plt.show()

# %%
# 3. LogSales vs DayOfWeek (color by Promo)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=train_n, x='DayOfWeek', y='LogSales', hue='Promo', alpha=0.3)
plt.title("LogSales vs DayOfWeek (Promo Highlighted)")
plt.xlabel("Day of Week")
plt.ylabel("Log of Sales")
plt.show()

# %%
# 4. Sales over time (sampled for performance)
plt.figure(figsize=(12, 6))
sampled_train = train_n.sample(10000)  # downsample for scatter plot performance
sns.scatterplot(x=sampled_train.index, y=sampled_train['Sales'], alpha=0.2)
plt.title("Sales Over Time (Sampled)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ### 2.5 Data Preparation and further Data Exploration

# %% [markdown]
# #### Data Prep! Table Store, Column CompetitionDistance: Fill NaN with a median value  (skewed distribuion)

# %%
# Missing values in table store
missing_values_table(store)
# Out:
# Your selected dataframe has 10 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
# Missing values for column store.CompetitionDistance
store[pd.isnull(store.CompetitionDistance)]
# Out:
# Empty DataFrame
# Columns: [Store, StoreType, Assortment, CompetitionDistance, CompetitionOpenSinceMonth, CompetitionOpenSinceYear, Promo2, Promo2SinceWeek, Promo2SinceYear, PromoInterval]
# Index: []

# %%
# fill NaN with a median value (skewed distribuion)
# No particular pattern was observed. In this case, it makes a sense to replace NaN with the median values
store['CompetitionDistance'].fillna(store['CompetitionDistance'].median(), inplace = True)

# %%
# Filter and print rows for Store 291, Store 622 and Store 879
filtered_stores = store[store['Store'].isin([291, 622, 879])]
filtered_stores
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 290    291         d          a               2325.0
# 621    622         a          c               2325.0
# 878    879         d          a               2325.0
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 290                        0.0                       0.0       0
# 621                        0.0                       0.0       0
# 878                        0.0                       0.0       1
#
#      Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 290              0.0              0.0                0
# 621              0.0              0.0                0
# 878              5.0           2013.0  Feb,May,Aug,Nov

# %% [markdown]
# #### Data Prep! Table Store, Column Promo2SinceWeek: Fill NaN with a median value (skewed distribuion)

# %%
# no promo = no information about the promo?
# Checking how many stores are marked as participating in Promo2 (Promo2 != 0), but are missing the week (Promo2SinceWeek) when the promotion started.
# Filters the store DataFrame to get only the rows where Promo2SinceWeek is missing. These are stored in the variable _.
_ = store[pd.isnull(store.Promo2SinceWeek)]
# From those rows with missing Promo2SinceWeek, this filters further to only those where Promo2 != 0.
# Rows that do participate in Promo2, but have missing information about when it started (Promo2SinceWeek isnull).
# .shape: Returns the dimensions (rows, columns) of the resulting DataFrame. This tells us how many such inconsistent rows exist.
_[_.Promo2 != 0].shape
# Out:
# (0, 10)

# %%
# There's no missing values for Promo2 but there's no information about the other Promo...Interval/week/year .
# Those values were replaced with zeros. The same procedure was performed for the variables related to the competitor,
# CompetitionOpenSinceMonth and CompetitionOpenSinceYear.
# replace NA's by 0
store.fillna(0, inplace = True)
store
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %% [markdown]
# #### Joing train and store data

# %%
# Joing tables train and store
print("Joining train set with an additional store information.")

# by specifying inner join we make sure that only those observations 
# that are present in both train and store sets are merged together
train_store = pd.merge(train_n, store, how = 'inner', on = 'Store')
test_store = pd.merge(test, store, how = 'inner', on = 'Store')

print("In total: ", train_store.shape)
train_store.head()
# Out:
# Joining train set with an additional store information.
# In total:  (844338, 23)
#    Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5   5263        555     1      1            0
# 1      2          5   6064        625     1      1            0
# 2      3          5   8314        821     1      1            0
# 3      4          5  13995       1498     1      1            0
# 4      5          5   4822        559     1      1            0
#
#    SchoolHoliday DayName  LogSales  ...  SalePerCustomer  StoreType  \
# 0              1  Friday  8.568646  ...         9.482883          c
# 1              1  Friday  8.710290  ...         9.702400          a
# 2              1  Friday  9.025816  ...        10.126675          a
# 3              1  Friday  9.546527  ...         9.342457          c
# 4              1  Friday  8.481151  ...         8.626118          a
#
#    Assortment  CompetitionDistance CompetitionOpenSinceMonth  \
# ...

# %%
# Exploring Data train_store
print(train_store.info())
# The info() method also tells us how many Non-Null values there are present in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844338 entries, 0 to 844337
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Store                      844338 non-null  int64
#  1   DayOfWeek                  844338 non-null  int64
#  2   Sales                      844338 non-null  int64
#  3   Customers                  844338 non-null  int64
#  4   Open                       844338 non-null  int64
#  5   Promo                      844338 non-null  int64
#  6   StateHoliday               844338 non-null  object
#  7   SchoolHoliday              844338 non-null  int64
#  8   DayName                    844338 non-null  object
#  9   LogSales                   844338 non-null  float64
#  10  Year                       844338 non-null  int32
#  11  Month                      844338 non-null  int32
#  12  Day                        844338 non-null  int32
# ...

# %% [markdown]
# #### 2.5.1 Distribution

# %% [raw]
# Analyze sales per store type:

# %%
train_store.groupby('StoreType')['Sales'].describe()
# Out:
#               count          mean          std     min      25%     50%  \
# StoreType
# a          457042.0   6925.697986  3277.351589    46.0  4695.25  6285.0
# b           15560.0  10233.380141  5155.729868  1252.0  6345.75  9130.0
# c          112968.0   6933.126425  2896.958579   133.0  4916.00  6408.0
# d          258768.0   6822.300064  2556.401455   538.0  5050.00  6395.0
#
#                 75%      max
# StoreType
# a           8406.00  41551.0
# b          13184.25  38722.0
# c           8349.25  31448.0
# d           8123.25  38037.0

# %% [raw]
# StoreType b has the lowest amount of data rows but the highest average sales.
# StoreType a has the highest amount of rows and the highest sales amount.

# %%
df = train_store.groupby('StoreType')[['Customers', 'Sales']].sum()

# %%
# create a color palette, mapped to these values

from matplotlib import cm
from matplotlib.colors import Normalize
cmap = cm.Blues

mini=min(df["Sales"])
maxi=max(df["Sales"])
norm = matplotlib.colors.Normalize(vmin=mini, vmax=maxi)
colors = [cmap(norm(value)) for value in df["Sales"]]

# %%
# Change color
# !pip install squarify
import squarify
squarify.plot(sizes=df["Customers"], alpha=.8, color=colors, label= df.index )
plt.title('Area size reflects the number of customers, Intensity of color reflects total sales for each type of store')
plt.axis('off')
plt.show()
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df= train_store.groupby('StoreType')[['Customers', 'Sales']].sum()
df_sorted = df.sort_values(by='Customers', ascending=False)
df_sorted
# Out:
#            Customers       Sales
# StoreType
# a          363541431  3165334859
# d          156904995  1765392943
# c           92129705   783221426
# b           31465616   159231395

# %%
# Values of Customers and Sales are highly correlated
df.corr()
# Out:
#            Customers     Sales
# Customers   1.000000  0.985145
# Sales       0.985145  1.000000

# %%
sns.catplot(
    data=train_store,
    x='Month',
    y='Sales',
    col='StoreType',     # one subplot per StoreType (horizontally)
    row='Promo',         # one row per Promo status
    hue='StoreType',
    palette='plasma',
    kind='point'         # or 'bar', 'box', etc. depending on what you want
)

# %%
sns.catplot(
    data=train_store,
    x='Year',
    y='Sales',
    col='StoreType',     # one subplot per StoreType (horizontally)
    row='Promo',         # one row per Promo status
    hue='StoreType',
    palette='plasma',
    kind='point'         # or 'bar', 'box', etc. depending on what you want
)

# %%
# sales trends
sns.catplot(data = train_store, x = 'Month', y = "Customers", 
               col = 'StoreType', # per store type in cols
               palette = 'plasma',
               hue = 'StoreType',
               row = 'Promo')

# %%
# sale per customer trends
sns.catplot(data = train_store, x = 'Month', y = "SalePerCustomer", 
               col = 'StoreType', # per store type in cols
               palette = 'plasma',
               hue = 'StoreType',
               row = 'Promo')

# %% [raw]
# 1.Univariate Analysis
# Numerical Variables
# Histogram / KDE Plot
#   For: Sales, Customers, SalePerCustomer, LogSales, CompetitionDistance
#   Use: seaborn.histplot, sns.kdeplot

# %%
numeric_cols = ['Sales', 'Customers', 'SalePerCustomer', 'LogSales', 'CompetitionDistance']
for col in numeric_cols:
    sns.histplot(train_store[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [raw]
# 1. Univariate Analysis
# Numerical Variables
# Box Plot
#   For detecting outliers in Sales, Customers, SalePerCustomer
#   Use: sns.boxplot

# %%
for col in ['Sales', 'Customers', 'SalePerCustomer']:
    sns.boxplot(x=train_store[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %% [raw]
# 1.Univariate Analysis
# Categorical Variables
# Count Plot
#   For: DayOfWeek, StoreType, Assortment, Promo, StateHoliday, SchoolHoliday, Promo2
#   Use: sns.countplot

# %%
cat_cols = ['DayOfWeek', 'StoreType', 'Assortment', 'Promo', 'StateHoliday', 'SchoolHoliday', 'Promo2']
for col in cat_cols:
    sns.countplot(x=col, data=train_store)
    plt.title(f'Count of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %% [raw]
# 2. Bivariate Analysis
# Numerical vs Numerical
# Scatter Plot
#  Sales vs Customers
#  SalePerCustomer vs CompetitionDistance

# %%
sns.scatterplot(x='Customers', y='Sales', data=train_store, alpha=0.3)
plt.title('Sales vs Customers')
plt.show()

# %%
sns.scatterplot(x='SalePerCustomer', y='CompetitionDistance', data=train_store, alpha=0.3)
plt.title('SalePerCustomer vs CompetitionDistance')
plt.show()

# %% [raw]
# 2. Bivariate Analysis
# Numerical vs Numerical
# Correlation Heatmap
#   For all numeric variables
#   Use: sns.heatmap(train_store.corr(), annot=True)

# %%
plt.figure(figsize=(14, 8))
corr = train_store.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [raw]
# 2. Bivariate Analysis
# Categorical vs Numerical
# Box Plot / Violin Plot
#   Sales by StoreType, Assortment, Promo, DayOfWeek, StateHoliday, SchoolHoliday
#   Use: sns.boxplot(x='StoreType', y='Sales', data=train_store)

# %%
sns.boxplot(x='StoreType', y='Sales', data=train_store)
plt.title('Sales by Store Type')
plt.show()

# %% [raw]
# 2. Bivariate Analysis
# Bar Plot (Aggregated Stats)
#  Average Sales or Customers per StoreType, DayName, Promo
#  Use: sns.barplot

# %%
avg_sales_dow = train_store.groupby('DayOfWeek')['Sales'].mean().reset_index()
sns.barplot(x='DayOfWeek', y='Sales', data=avg_sales_dow)
plt.title('Average Sales by Day of Week')
plt.show()

# %% [raw]
# 3. Time Series Exploration
# Line Plot Over Time
#   Aggregate daily/weekly Sales over Date (can be reconstructed from Year/Month/Day)
#   Use: plt.plot or sns.lineplot

# %%
# Create date column
train_store['Date'] = pd.to_datetime(train_store[['Year', 'Month', 'Day']])

# %%
daily_sales = train_store.groupby('Date')['Sales'].sum().reset_index()
sns.lineplot(x='Date', y='Sales', data=daily_sales)
plt.title('Daily Total Sales Over Time')
plt.show()

# %% [raw]
# 3. Time Series Exploration
# Seasonality Check
#   Sales by Month, DayOfWeek, Year
#   Use: sns.boxplot or sns.lineplot

# %%
sns.boxplot(x='Month', y='Sales', data=train_store)
plt.title('Monthly Sales Distribution')
plt.show()

# %% [raw]
# 4. Multivariate / Advanced Visuals
# FacetGrid / Subplots
#   Sales trends per StoreType, Promo, Assortment
#   Use: sns.FacetGrid

# %%
g = sns.FacetGrid(train_store, col='Promo', row='StoreType', margin_titles=True)
g.map_dataframe(sns.histplot, x='Sales', bins=30)
g.set_titles(row_template='{row_name}', col_template='Promo {col_name}')
plt.show()

# %% [raw]
# 4. Multivariate / Advanced Visuals
# Pair Plot
#   Explore relationships between Sales, Customers, CompetitionDistance, SalePerCustomer
#   Use: sns.pairplot

# %%
# Select a subset of numeric features
pairplot_cols = ['Sales', 'Customers', 'SalePerCustomer', 'CompetitionDistance']

# Create pairplot
sns.pairplot(train_store[pairplot_cols], diag_kind='kde', plot_kws={'alpha': 0.2})
plt.suptitle('Pairplot of Sales, Customers, SalePerCustomer, and CompetitionDistance', y=1.02)
plt.show()

# %%
#color-code by a category (e.g., Promo or StoreType)
sns.pairplot(train_store[pairplot_cols + ['Promo']], hue='Promo', diag_kind='kde', plot_kws={'alpha': 0.2})
plt.suptitle('Pairplot Colored by Promo', y=1.02)
plt.show()

# %% [raw]
# 4. Multivariate / Advanced Visuals
# Heatmap for Store-Day activity
#   Pivot table with average Sales per Store and DayOfWeek
#   Use: sns.heatmap(pivot_table)

# %%
# Pivot table: average sales per Store and DayOfWeek
pivot_table = train_store.pivot_table(
    index='Store',
    columns='DayOfWeek',
    values='Sales',
    aggfunc='mean'
)

# Create the heatmap
plt.figure(figsize=(16, 10))
sns.heatmap(pivot_table, cmap='YlGnBu', linewidths=0.1, linecolor='gray')
plt.title('Average Sales per Store and Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Store')
plt.show()

# %% [markdown]
# #### 2.4.2 Correlations

# %% [markdown]
# #### 2.4.3 Time-Series Analysis

# %% [markdown]
# ### 2.5 Data Exploration Report

# %% [raw]
# Findings:
# Strong correlation between Sales per customer and Promo
# No notable effect for sales when the promotion continue in time
# 17.0% of the sales records (172871) on the Train dataset
# The stores presented as closed and no sales where suppressed of the dataset, in total (172817)
# 17.0% of the customer records (172869) on the Train dataset, all this records were suppressed with the records of 0 sales mentioned early.
# There is 54 days of open stores with 0 sales are still in the dataset, those are considered real events (Eg. a manifestation)

# %% [markdown]
# ## 3. Data Preparation

# %% [markdown]
# ### 3.1 Select Data

# %% [markdown]
# ### 3.2 Clean Data

# %% [markdown]
# ### 3.3 Construct Data

# %% [markdown]
# ### 3.4 Integrate Data

# %% [markdown]
# ### 3.5 Format Data

# %% [markdown]
# ## 4. Modelling

# %% [markdown]
# ### 4.1 Time Series Analysis and Forecasting

# %%
# using dataframe train_store

# remove closed stores and those with no sales
df = train_store[(train_store["Open"] != 0) & (train_store['Sales'] != 0)]

# sales for the store number 1 (StoreType C)
sales = train_store[train_store.Store == 14].loc[:, ['Date', 'Sales']]

# reverse to the order: from 2013 to 2015
sales = sales.sort_index(ascending = False)

# to datetime64
sales['Date'] = pd.DatetimeIndex(sales['Date'])
sales.dtypes
# Out:
# Date     datetime64[ns]
# Sales             int64
# dtype: object

# %%
# from the prophet documentation every variables should have specific names
sales = sales.rename(columns = {'Date': 'ds',
                                'Sales': 'y'})
sales.head()
# Out:
#                ds     y
# 843223 2013-01-02  5253
# 842114 2013-01-03  4169
# 841006 2013-01-04  4734
# 839899 2013-01-05  2519
# 838774 2013-01-07  7788

# %%
# plot daily sales
ax = sales.set_index('ds').plot(figsize = (12, 4))
ax.set_ylabel('Daily Number of Sales')
ax.set_xlabel('Date')
plt.show()

# %% [markdown]
# #### Modeling Holidays

# %%
# create holidays dataframe
state_dates = df[(df.StateHoliday == 'a') | (df.StateHoliday == 'b') & (df.StateHoliday == 'c')].loc[:, 'Date'].values
school_dates = df[df.SchoolHoliday == 1].loc[:, 'Date'].values

state = pd.DataFrame({'holiday': 'state_holiday',
                      'ds': pd.to_datetime(state_dates)})
school = pd.DataFrame({'holiday': 'school_holiday',
                      'ds': pd.to_datetime(school_dates)})

holidays = pd.concat((state, school))
holidays.head()
# Out:
#          holiday         ds
# 0  state_holiday 2015-06-04
# 1  state_holiday 2015-06-04
# 2  state_holiday 2015-06-04
# 3  state_holiday 2015-06-04
# 4  state_holiday 2015-06-04

# %%
# Install prophet
# !pip install prophet
# from prophet import Prophet

# set the uncertainty interval to 95% (the Prophet default is 80%)
my_model = Prophet(interval_width = 0.95,
                   holidays = holidays)
my_model.fit(sales)

# dataframe that extends into future 6 weeks
future_dates = my_model.make_future_dataframe(periods = 6*7)

print("First week to forecast.")
future_dates.tail(7)
# Out:
# 11:53:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:46 - cmdstanpy - INFO - Chain [1] done processing
# First week to forecast.
#             ds
# 814 2015-09-05
# 815 2015-09-06
# 816 2015-09-07
# 817 2015-09-08
# 818 2015-09-09
# 819 2015-09-10
# 820 2015-09-11

# %%
# predictions
forecast = my_model.predict(future_dates)

# preditions for last week
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 814 2015-09-05  2791.126885   799.870272  4779.761083
# 815 2015-09-06  4725.073250  2649.598730  6527.569442
# 816 2015-09-07  6012.213280  4015.591129  7980.865771
# 817 2015-09-08  5092.914886  3189.543315  6933.519216
# 818 2015-09-09  4674.702984  2760.752853  6634.655039
# 819 2015-09-10  4778.520740  2805.963212  6678.245924
# 820 2015-09-11  5053.981072  3160.493253  6981.480300

# %%
fc = forecast[['ds', 'yhat']].rename(columns = {'Date': 'ds', 'Forecast': 'yhat'})

# %%
# visualizing predicions
my_model.plot(forecast);

# %%
my_model.plot_components(forecast);

# %% [markdown]
# ## Appendix

# %% [raw]
# PART I: Using Catplot instead of Boxplot

# %%
# Reducing train_store to sales <= 12500
train_store_red = train_store[train_store.Sales <= 12500]
print("Reduced dataset train_store: ", train_store_red.shape)
# Out:
# Reduced dataset train_store:  (799603, 23)

# %%
# Catplot  Storetype and Sales for reduced dataset
sns.catplot(x='StoreType', y='Sales', data=train_store_red, kind='box', height=6, aspect=1.5)

# %%
# Catplot  Storetype and Sales for sample dataset
plt.figure(figsize=(12, 6))
sampled_train_store = train_store.sample(10000)  # downsample for scatter plot performance

# %%
# Catplot  Storetype and Sales for sample dataset
sns.catplot(x='StoreType', y='Sales', data=sampled_train_store, kind='box', height=6, aspect=1.5)

# %% [raw]
# PART II: Using additional functions to explore data

# %% [raw]
# df.value_counts() - Counts unique values in a column (e.g., df['col'].value_counts())
# df['col'].nunique() - Returns the number of unique values in a column
# df['col'].unique() - Returns an array of unique values in a column
# df['col'].isnull().sum() - Counts missing values in a column
# df['col'].duplicated().sum() - Counts duplicated entries in a column
# df.corr() - Returns pairwise correlation of numeric columns
# df.skew() / df.kurt() - Measures skewness or kurtosis of distributions
# df.mode() - Returns the most frequent value(s) in each column

# %%
# df.value_counts() - Counts unique values in a column (e.g., df['col'].value_counts())
train_store['DayOfWeek'].value_counts()
# Out:
# DayOfWeek
# 6    144052
# 2    143955
# 3    141922
# 5    138633
# 1    137557
# 4    134626
# 7      3593
# Name: count, dtype: int64

# %%
# df['col'].nunique() - Returns the number of unique values in a column
train_store['DayOfWeek'].nunique()
# Out:
# 7

# %%
# df['col'].unique() - Returns an array of unique values in a column
train_store['DayOfWeek'].unique()
# Out:
# array([5, 4, 3, 2, 1, 7, 6], dtype=int64)

# %%
# df['col'].isnull().sum() - Counts missing values in a column
train_store['DayOfWeek'].isnull().sum()
# Out:
# 0

# %%
# df['col'].duplicated().sum() - Counts duplicated entries in a column
train_store['DayOfWeek'].duplicated()
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 844333     True
# 844334     True
# 844335     True
# 844336     True
# 844337     True
# Name: DayOfWeek, Length: 844338, dtype: bool

# %%
# df['col'].duplicated().sum() - Counts duplicated entries in a column
train_store['DayOfWeek'].duplicated().sum()
# Out:
# 844331

# %%
# df.corr() - Returns pairwise correlation of numeric columns
# not running so far
# train_store.corr()
# corr_matrix_train_store = train_store.corr()
# print(corr_matrix_train_store)

# %%
# Correlation matrix could not be generated so far
# plt.figure(figsize=(12, 10))
# sns.heatmap(corr_matrix_train_store, annot=True, cmap='coolwarm', fmt=".2f")
# plt.title('Correlation Matrix')
# plt.show()

# %%
# df.skew() - Measures skewness of distributions
# not running so far
# train_store.skew()

# %%
# df.kurt() - Measures kurtosis of distributions
# not running so far
# train_store.kurt()

# %%
# df.mode() - Returns the most frequent value(s) in each column
train_store.mode()
# Out:
#    Store  DayOfWeek   Sales  Customers  Open  Promo StateHoliday  \
# 0     85        6.0  5674.0      560.0   1.0    0.0            0
# 1    262        NaN     NaN        NaN   NaN    NaN          NaN
# 2    335        NaN     NaN        NaN   NaN    NaN          NaN
# 3    423        NaN     NaN        NaN   NaN    NaN          NaN
# 4    494        NaN     NaN        NaN   NaN    NaN          NaN
# 5    562        NaN     NaN        NaN   NaN    NaN          NaN
# 6    682        NaN     NaN        NaN   NaN    NaN          NaN
# 7    733        NaN     NaN        NaN   NaN    NaN          NaN
# 8    769        NaN     NaN        NaN   NaN    NaN          NaN
# 9   1097        NaN     NaN        NaN   NaN    NaN          NaN
#
#    SchoolHoliday   DayName  LogSales  ...  SalePerCustomer  StoreType  \
# 0            0.0  Saturday  8.643826  ...              9.0          a
# 1            NaN       NaN       NaN  ...              NaN        NaN
# ...
